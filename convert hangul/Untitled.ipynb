# %%
import os
import re

# %%
def convert_hangul(dirname):
    try:   
    
        file_list = os.listdir(dirname)
#     print(file_list)
        for full_list in file_list:
            full_file = os.path.join(dirname, full_list)
        
            if os.path.isdir(full_file):
                convert_hangul(full_file)
            
            else:
                ext = os.path.splitext(full_file)[-1]
                patten = '[^ㄱ-ㅣ가-힣]+'
                repl = ''
                cnt = 0
#                 print(ext)
                if ext == '.jpg':
                    m = re.sub(pattern=patten, repl = repl, string = '{}'.format(cnt))
                    re.compile('[|]')
#                     z = re.compile('[ㄱ-ㅎ]+').findall(full_list)
#                     print(z)
#                     os.rename('D:/데이터 수집/마스크 데이터 어노테이션 완성(3100장)/사진 변환/'+full_list, 'D:/데이터 수집/마스크 데이터 어노테이션 완성(3100장)/사진 변환/'+m)
#                     print(m)
                    
                if ext == '.txt':
                    m = re.sub(pattern=patten, repl = repl, string = '{}'.format(cnt))
#                     os.rename('D:/데이터 수집/마스크 데이터 어노테이션 완성(3100장)/사진 변환/'+full_list, 'D:/데이터 수집/마스크 데이터 어노테이션 완성(3100장)/사진 변환/'+m)
                    
                cnt = cnt+1    
#                 if ext == '.png':    
                
                
                
                
            
    except PermissionError:
        pass

# %%
convert_hangul('D:\데이터 수집\마스크 데이터 어노테이션 완성(3100장)\사진 변환')
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...
