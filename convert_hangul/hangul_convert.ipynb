# %%
import os
import re

# %%
def file_name_del(dirname):
    try:
        txt_list = os.listdir(dirname)
        
        for txt in txt_list:
            full_file = os.path.join(dirname, txt)
            
            if os.path.isdir(full_file):
                file_name_del(full_file)
                
            else:
                
                
                
#                 ext = os.path.splitext(full_file)[-1]
                
                replace_path = full_file.replace("\\",'/')
                file_split = replace_path.split('/')[-2]
                korean = re.compile('[\u3131-\u3163\uac00-\ud7a3]+')#한글 제외하기
                
#                 # 한글삭제

                parseText= re.sub(replace_path.strip(), '', file_split)
                print(parseText)
                
# #                 hangul = re.compile("[^ㄱ-ㅣ 가-힣]+")
# #                 repl =''
# #                 text = '{}'.format(txt)
# #                 result = hangul.sub("",file_split)
# #                 print(result)
# #                 minus = re.sub(pattern= pattern, repl = repl, string = txt)
                
# #                 replace_name=replace_path.replace('충남', 'Chungnam')
                              
                
#                 os.rename('D:/Data_collection/차량 데이터_hangul/한글 covert 전/2020_04_20/2020_04_20/'+file_split, 'D:/Data_collection/차량 데이터_hangul/한글 covert 전/2020_04_20/2020_04_20/'+parseText)
#                 replace_name1=replace_path.replace('저', 'ju')
#                 os.rename(replace_path, replace_name1)
                
    except PermissionError:
        pass

# %%
file_name_del('D:/Data_collection/car_data/car_load_data/image_convert/night')
# Out:
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# 000810 (5-20-2020 3-59-47 PM)
# ...

# %%
def file_hangul_del(dirname):
    try:
        txt_list = os.listdir(dirname)
        
        for txt in txt_list:
            full_file = os.path.join(dirname, txt)
            
            if os.path.isdir(full_file):
                file_name_del(full_file)
                
            else:
                
                
                
#                 ext = os.path.splitext(full_file)[-1]
                
                replace_path = full_file.replace("\\",'/')
                
                file = replace_path.split('/')[-1]
                hangul = re.compile("[^ㄱ-ㅣ 가-힣]+")
                                                                                
                result = hangul.sub("",file)
                #print(result)
                if result == []:
                    pass
                elif result == "":
                    pass
                elif result == "[]":
                    pass
                else:
                    hangul_list = []
                    hangul_list.append(result)
                    print(hangul_list)
                    
                    
    except PermissionError:
        pass

# %%
file_hangul_del('D:/Data_collection/차량데이터/새 폴더')

# %%
testText = 'asdfasdfㅋㅌㅊㅍㅋㅌㅊㅍ1234234가나다라*@*@#*#@*'





korean = re.compile('[\u3131-\u3163\uac00-\ud7a3]+')



# 한글삭제

parseText= re.sub(korean, '', testText)
print(parseText)


# 특수문자 삭제

parseText= re.sub('[-=.#/?:$}]', '', text)
print(parseText)
# Out:
# asdfasdf1234234*@*@#*#@*
# ㅋㅋㅋ 안녕하세요 ~~ df

# %%
for i in os.path.isdir('D:/Data_collection/car_data/car_load_data/image_convert/night'):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-a16543a31937> in <module>
# ----> 1 for i in os.path.isdir('D:/Data_collection/car_data/car_load_data/image_convert/night'):
#       2     print(i)
#
# TypeError: 'bool' object is not iterable
