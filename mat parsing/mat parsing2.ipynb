# %%
import os
import re
import cv2

# %%
def txt_lists(dirname):
    try:
        file_list = os.listdir(dirname)
        
        for file in file_list:
            txt_files = os.path.join(dirname, file)
            
            if os.path.isdir(txt_files):
                txt_lists(txt_files)
                
            else:
                ext = os.path.splitext(txt_files)[-1]
                
                if ext == '.txt':
#                     parsing(txt_files)
                    print()
        
    except PermissionError:
        pass
    

    
def parsing(filename):
    label = ''
    pase = ''
#     image = cv2.imread(filename)
#     height, width, channel = image.shape
    f1 = open(filename, 'r')
    while True:
        line = f1.readline()
        
        if not line:
            break
        label = label + line    
        labels = label.split()
        
        lts = listToStringWithoutBrackets(labels)
#         labeling = 'x '+'y '+'w '+'h '+'x1 '+'y1 '+'x2 '+'y2 '+'occ_type'+'\n'
#         pase = pase + lts.split('\'')[1]+' '+lts.split('\'')[3]+' '+lts.split('\'')[5]+' '+lts.split('\'')[7]+' '+lts.split('\'')[9]+' '+lts.split('\'')[11]+' '+lts.split('\'')[13]+' '+lts.split('\'')[15]+' '+lts.split('\'')[25]
        
        new_filename = filename.replace('matpar','new_matpar')
        
    f1.close()
    dir = new_filename.replace('\\','/').split('/')
    new_path = dir[0] + '/'
        
    for i in range(1, len(dir)-1):
        new_path = os.path.join(new_path, dir[i])
        if not os.path.isdir(new_path):
            os.makedirs(os.path.join(new_path))
                
    with open(new_filename, 'w') as f2:
#         f2.write(labeling)
        if label.split()[0] == '[':
            f2.write(label.split()[1])
            f2.write(' ')
            f2.write(label.split()[2])
            f2.write(' ')
            f2.write(label.split()[3])
            f2.write(' ')
            f2.write(label.split()[4])
            f2.write(' ')
            f2.write(label.split()[5])
            f2.write(' ')
            f2.write(label.split()[6])
            f2.write(' ')
            f2.write(label.split()[7])
            f2.write(' ')
            f2.write(label.split()[8])
            f2.write(' ')
            f2.write(label.split()[13])
            f2.write(' ')
#             f2.write(width)
#             f2.write(' ')
#             f2.write(height)
    
        else:
            f2.write(lts.split('\'')[1])
            f2.write(' ')
            f2.write(lts.split('\'')[3])
            f2.write(' ')
            f2.write(lts.split('\'')[5])
            f2.write(' ')
            f2.write(lts.split('\'')[7])
            f2.write(' ')
            f2.write(lts.split('\'')[9])
            f2.write(' ')
            f2.write(lts.split('\'')[11])
            f2.write(' ')
            f2.write(lts.split('\'')[13])
            f2.write(' ')
            f2.write(lts.split('\'')[15])
            f2.write(' ')
            f2.write(lts.split('\'')[25])
#             f2.write(width)
#             f2.write(' ')
#             f2.write(height)

        
        

txt_lists('D:/matpar')

# %%
def image_parsing(dirname):
    try:
        Train_image = os.listdir(dirname)

        for file in Train_image:
            full_file = os.path.join(dirname, file)

            if os.path.isdir(full_file):
                image_parsing(full_file)

            else:
                ext = os.path.splitext(full_file)[-1]

                image_list = []
                

                if ext == '.jpg':
                    image_list.append(full_file)
                
#                 cutting = image_list.replace('\\','/')
                print(cutting)
#                 print(cutting+'영역')
                image_ori = cv2.imread(cutting)
                hights, width, channel = image_ori.shape
                print("{} width의 경우  ".format(width))

                split_text = listToStringWithoutBrackets(image_list)
                split_text = split_text.replace('\\','/').split('/')

                split_image_name = split_text[-1].split('.')
                print(split_image_name[0])
                
                
            
            
    except PermissionError:
        pass

# %%
image_parsing('C:/Users/power/Desktop/mask_data/images')
# Out:
# C:/Users/power/Desktop/mask_data/images/label.txt
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-c54ad79937de> in <module>
# ----> 1 image_parsing('C:/Users/power/Desktop/mask_data/images')
#
# <ipython-input-3-b6c663c82377> in image_parsing(dirname)
#      22 #                 print(cutting+'영역')
#      23                 image_ori = cv2.imread(cutting)
# ---> 24                 hights, width, channel = image_ori.shape
#      25                 print("{} width의 경우  ".format(width))
#      26
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
def txt_modify(dirname):
    try:
        txt_file = os.listdir(dirname)
        
        for file in txt_file:
            full_file = os.path.join(dirname, file)
            
            if os.path.isdir(full_file):
                txt_sujung(full_file)
                
            else:
                ext = os.path.splitext(full_file)[-1]
                txt_files = []
                if ext == '.txt':
                    txt_files.append(full_file)
                    
                    
                    
                    
        return txt_files
        
    except:
        pass

# %%
def cleanText(readData):
 
    #텍스트에 포함되어 있는 특수 문자 제거
 
    text = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', '', readData)
 
    return text

def listToStringWithoutBrackets(list1):
    return str(list1).replace('[','').replace(']','')

# %%
import cv2
image = cv2.imread('C:/Users/power/Desktop/mask_data/images/test_00000001.jpg',cv2.IMREAD_ANYCOLOR)

# %%
height, width, channel = image.shape
print(height, width, channel)
# Out:
# 2329 3500 3

# %%
img_ori = cv2.imread('C:/Users/power/finance/opencv study/license_plate_recognition/1.jpg')#이미지 불러오기
height, width, channel = img_ori.shape# 너비,높이,채널 값 주기

print(height, width, channel)
# Out:
# 626 940 3

# %%
img_ori = cv2.imread('C:/Users/power/Desktop/지워버릴 파일/images/test_00000001.jpg')#이미지 불러오기
height, width, channel = img_ori.shape# 너비,높이,채널 값 주기

print(height, width, channel)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-0e434ba0ea87> in <module>
#       1 img_ori = cv2.imread('C:/Users/power/Desktop/지워버릴 파일/images/test_00000001.jpg')#이미지 불러오기
# ----> 2 height, width, channel = img_ori.shape# 너비,높이,채널 값 주기
#       3
#       4 print(height, width, channel)
#
# AttributeError: 'NoneType' object has no attribute 'shape'
